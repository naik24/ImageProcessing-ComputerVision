# %% [markdown]
# ## Importing Libraries

# %%
import cv2
import glob
import random
import numpy as np

# %% [markdown]
# ## Required Functions

# %%
#%% ========== distance computing function ==========
def computeDist(p1, p2):
  return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)


#%% ========== mean shift algorithm ==========
def meanShift(imageFiles, dataReductionIndices, radius = 10):
    # initialize empty least to store means
    imageMeans = []
    imageCounter = 1
    for img in imageFiles:
        filename = img.split('/')[-1]
        print(f"\n========== Finding Mean for: {filename} (Image: {imageCounter} / {len(imageFiles)})==========")
        inputImage = cv2.imread(img)
        featureSpace = []
        
        # build 3D feature space using RGB values
        print("\nBuilding Feature Space")
        for i in range(inputImage.shape[0]):
            for j in range(inputImage.shape[1]):
                featureSpace.append([inputImage[i, j, 0], inputImage[i, j, 1], inputImage[i, j, 2]])
        featureSpace = np.array(featureSpace, dtype = 'int64')
        
        if dataReductionIndices != 0:    
            featureSpace = np.delete(featureSpace, dataReductionIndices, axis = 0)
        print("Building Feature Space...Done")
        
        # initializing random seed
        print("\nInitializing Random Seed")
        idx = random.sample(range(len(featureSpace)), 1)[0]
        initialSeed = featureSpace[idx]
        print("Initializing Random Seed...Done")
        
        # mean-shift parameter
        radius = radius
        
        # convergence loop
        print("\nFinding Center of Mass")
        ctr = 1
        while True:
            print(f"\nIteration: {ctr}")
            print(f"Mean: {initialSeed}")
            inRadiusPoints = [] # list to store points which are within the radius from the current centroid
            for point in featureSpace:
                dist = computeDist(point, initialSeed)
                if dist < radius:
                    inRadiusPoints.append(point)
            inRadiusPoints = np.array(inRadiusPoints)
            
            newMean = np.mean(inRadiusPoints, axis = 0, dtype = 'int')
            if (newMean == initialSeed).all() == False:
                initialSeed = newMean
                ctr += 1 
            else:
                print("Converged")
                break        
        print("Finding Center of Mass...Done")
        imageMeans.append([filename, list(newMean)])
        imageCounter +=1
        
    return imageMeans

#%% ========== preparing subsets ==========
def formSubsets(imageMeans, radius = 10):
    subsets = [] # list to store final subsets
    clusteredImages = [] # list to maintain the list of images which have been already assigned a subset
    for i in range(len(imageMeans)):
        currentSet = []
        currentMean = imageMeans[i]
        if imageMeans[i][0] not in clusteredImages:
            clusteredImages.append(imageMeans[i][0])
            currentSet.append(imageMeans[i][0])
            for j in range(len(imageMeans)):
                if imageMeans[j][0] not in clusteredImages:
                    dist = computeDist(currentMean[1], imageMeans[j][1])
                    if dist < radius:
                        currentSet.append(imageMeans[j][0])
                        clusteredImages.append(imageMeans[j][0])
        if len(currentSet) != 0:
            subsets.append(currentSet)
    
    for i in range(len(subsets)):
        print(f"\n ========== subset: {i} ==========")
        print(subsets[i])

# %% [markdown]
# ## Main Function

# %%
def main(dataReductionPercentage = 0):
    imageFilesA = glob.glob('partADataset/*.jpg') # fountainP11, Herz-Jesus P8, entry P10
    imageFilesB = glob.glob('partBDataset/*.jpg') # entry P10, Castle P19
    
    # There are in total 6 million features. 97% of them have been removed to increase (next line)
    # computation time. Change drp value to remove only a certain percentage of features
    if dataReductionPercentage != 0:
        dataReductionIndices = random.sample(range(2048 * 3072), int(2048 * 3072 * dataReductionPercentage))
    else:
        dataReductionIndices = 0
        
    radius = 50
    
    # pass imageFilesA/imageFilesB below to test for different combination of images
    means = meanShift(imageFilesB, dataReductionIndices, radius) # compute means using mean shift
    formSubsets(means, radius) # form subsets based on the means obtained

main(dataReductionPercentage = 0.97)
# Out:
# ========== Finding Mean for: castleP19_0009.jpg (Image: 1 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [100  68  63]
#
# Iteration: 2
# Mean: [96 69 65]
#
# Iteration: 3
# Mean: [95 69 65]
#
# Iteration: 4
# Mean: [94 68 64]
#
# Iteration: 5
# Mean: [93 68 64]
#
# Iteration: 6
# Mean: [93 67 64]
#
# Iteration: 7
# Mean: [93 67 63]
#
# Iteration: 8
# Mean: [92 67 63]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0008.jpg (Image: 2 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [107  94 102]
#
# Iteration: 2
# Mean: [118  86  80]
#
# Iteration: 3
# Mean: [114  83  76]
#
# Iteration: 4
# Mean: [111  80  74]
#
# Iteration: 5
# Mean: [108  78  72]
#
# Iteration: 6
# Mean: [106  76  71]
#
# Iteration: 7
# Mean: [104  75  70]
#
# Iteration: 8
# Mean: [103  74  69]
#
# Iteration: 9
# Mean: [102  74  69]
#
# Iteration: 10
# Mean: [102  73  69]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0018.jpg (Image: 3 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [157 111  93]
#
# Iteration: 2
# Mean: [158 116 100]
#
# Iteration: 3
# Mean: [159 117 100]
#
# Iteration: 4
# Mean: [159 117 101]
#
# Iteration: 5
# Mean: [160 117 101]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: entryP10_0003.jpg (Image: 4 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [109  96 122]
#
# Iteration: 2
# Mean: [125  98  98]
#
# Iteration: 3
# Mean: [132 101  96]
#
# Iteration: 4
# Mean: [136 104  98]
#
# Iteration: 5
# Mean: [139 106  99]
#
# Iteration: 6
# Mean: [141 107 100]
#
# Iteration: 7
# Mean: [143 108 101]
#
# Iteration: 8
# Mean: [144 109 101]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: entryP10_0002.jpg (Image: 5 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [167 128 106]
#
# Iteration: 2
# Mean: [158 120 109]
#
# Iteration: 3
# Mean: [153 116 106]
#
# Iteration: 4
# Mean: [150 114 105]
#
# Iteration: 5
# Mean: [148 113 104]
#
# Iteration: 6
# Mean: [147 112 104]
#
# Iteration: 7
# Mean: [147 112 103]
#
# Iteration: 8
# Mean: [147 111 103]
#
# Iteration: 9
# Mean: [146 111 103]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: entryP10_0000.jpg (Image: 6 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [84 54 49]
#
# Iteration: 2
# Mean: [84 61 60]
#
# Iteration: 3
# Mean: [88 65 64]
#
# Iteration: 4
# Mean: [93 69 67]
#
# Iteration: 5
# Mean: [97 72 70]
#
# Iteration: 6
# Mean: [101  75  72]
#
# Iteration: 7
# Mean: [104  77  75]
#
# Iteration: 8
# Mean: [107  79  76]
#
# Iteration: 9
# Mean: [109  81  78]
#
# Iteration: 10
# Mean: [110  82  79]
#
# Iteration: 11
# Mean: [111  83  80]
#
# Iteration: 12
# Mean: [112  84  80]
#
# Iteration: 13
# Mean: [113  84  81]
#
# Iteration: 14
# Mean: [114  85  81]
#
# Iteration: 15
# Mean: [114  85  82]
#
# Iteration: 16
# Mean: [115  86  82]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: entryP10_0001.jpg (Image: 7 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [124  91  82]
#
# Iteration: 2
# Mean: [122  91  86]
#
# Iteration: 3
# Mean: [122  92  86]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: entryP10_0005.jpg (Image: 8 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [102  79  77]
#
# Iteration: 2
# Mean: [108  83  82]
#
# Iteration: 3
# Mean: [115  88  86]
#
# Iteration: 4
# Mean: [121  92  90]
#
# Iteration: 5
# Mean: [125  96  93]
#
# Iteration: 6
# Mean: [128  99  96]
#
# Iteration: 7
# Mean: [132 101  97]
#
# Iteration: 8
# Mean: [135 103  99]
#
# Iteration: 9
# Mean: [138 106 101]
#
# Iteration: 10
# Mean: [141 108 103]
#
# Iteration: 11
# Mean: [144 110 104]
#
# Iteration: 12
# Mean: [146 112 105]
#
# Iteration: 13
# Mean: [148 113 106]
#
# Iteration: 14
# Mean: [149 114 106]
#
# Iteration: 15
# Mean: [149 114 107]
#
# Iteration: 16
# Mean: [150 114 107]
#
# Iteration: 17
# Mean: [150 115 107]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: entryP10_0004.jpg (Image: 9 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [158 120 116]
#
# Iteration: 2
# Mean: [156 119 110]
#
# Iteration: 3
# Mean: [155 118 109]
#
# Iteration: 4
# Mean: [154 118 109]
#
# Iteration: 5
# Mean: [154 117 109]
#
# Iteration: 6
# Mean: [153 117 109]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: entryP10_0006.jpg (Image: 10 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [124 107 116]
#
# Iteration: 2
# Mean: [137 106 102]
#
# Iteration: 3
# Mean: [142 108 102]
#
# Iteration: 4
# Mean: [145 111 104]
#
# Iteration: 5
# Mean: [147 112 105]
#
# Iteration: 6
# Mean: [148 113 106]
#
# Iteration: 7
# Mean: [149 114 106]
#
# Iteration: 8
# Mean: [150 114 106]
#
# Iteration: 9
# Mean: [150 115 106]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: entryP10_0007.jpg (Image: 11 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [125  83  71]
#
# Iteration: 2
# Mean: [119  88  82]
#
# Iteration: 3
# Mean: [120  90  85]
#
# Iteration: 4
# Mean: [122  92  87]
#
# Iteration: 5
# Mean: [124  94  88]
#
# Iteration: 6
# Mean: [126  95  89]
#
# Iteration: 7
# Mean: [128  96  90]
#
# Iteration: 8
# Mean: [130  98  91]
#
# Iteration: 9
# Mean: [132  99  92]
#
# Iteration: 10
# Mean: [133 101  93]
#
# Iteration: 11
# Mean: [135 102  94]
#
# Iteration: 12
# Mean: [136 103  95]
#
# Iteration: 13
# Mean: [137 104  96]
#
# Iteration: 14
# Mean: [138 104  96]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: entryP10_0009.jpg (Image: 12 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [183 137 119]
#
# Iteration: 2
# Mean: [165 124 109]
#
# Iteration: 3
# Mean: [155 117 104]
#
# Iteration: 4
# Mean: [149 112 100]
#
# Iteration: 5
# Mean: [145 109  97]
#
# Iteration: 6
# Mean: [143 107  96]
#
# Iteration: 7
# Mean: [141 106  95]
#
# Iteration: 8
# Mean: [140 105  94]
#
# Iteration: 9
# Mean: [139 104  94]
#
# Iteration: 10
# Mean: [138 104  93]
#
# Iteration: 11
# Mean: [138 103  93]
#
# Iteration: 12
# Mean: [137 103  93]
#
# Iteration: 13
# Mean: [137 102  92]
#
# Iteration: 14
# Mean: [136 102  92]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: entryP10_0008.jpg (Image: 13 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [52 43 39]
#
# Iteration: 2
# Mean: [56 43 45]
#
# Iteration: 3
# Mean: [61 46 48]
#
# Iteration: 4
# Mean: [65 50 51]
#
# Iteration: 5
# Mean: [70 53 54]
#
# Iteration: 6
# Mean: [74 56 57]
#
# Iteration: 7
# Mean: [78 59 60]
#
# Iteration: 8
# Mean: [82 62 62]
#
# Iteration: 9
# Mean: [85 64 64]
#
# Iteration: 10
# Mean: [88 66 66]
#
# Iteration: 11
# Mean: [91 68 68]
#
# Iteration: 12
# Mean: [94 71 70]
#
# Iteration: 13
# Mean: [98 73 72]
#
# Iteration: 14
# Mean: [101  76  74]
#
# Iteration: 15
# Mean: [104  78  76]
#
# Iteration: 16
# Mean: [107  80  78]
#
# Iteration: 17
# Mean: [110  83  79]
#
# Iteration: 18
# Mean: [113  85  81]
#
# Iteration: 19
# Mean: [116  87  83]
#
# Iteration: 20
# Mean: [119  89  84]
#
# Iteration: 21
# Mean: [121  91  86]
#
# Iteration: 22
# Mean: [124  93  87]
#
# Iteration: 23
# Mean: [126  95  88]
#
# Iteration: 24
# Mean: [128  97  90]
#
# Iteration: 25
# Mean: [131  98  91]
#
# Iteration: 26
# Mean: [133 100  92]
#
# Iteration: 27
# Mean: [135 102  94]
#
# Iteration: 28
# Mean: [138 104  95]
#
# Iteration: 29
# Mean: [140 105  96]
# Iteration: 30
# Mean: [141 106  97]
#
# Iteration: 31
# Mean: [142 107  98]
#
# Iteration: 32
# Mean: [143 108  98]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0003.jpg (Image: 14 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [118  81  77]
#
# Iteration: 2
# Mean: [114  83  76]
#
# Iteration: 3
# Mean: [113  82  75]
#
# Iteration: 4
# Mean: [113  81  75]
#
# Iteration: 5
# Mean: [112  81  75]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0017.jpg (Image: 15 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [128  91  77]
#
# Iteration: 2
# Mean: [134  97  84]
#
# Iteration: 3
# Mean: [142 103  89]
#
# Iteration: 4
# Mean: [148 108  92]
#
# Iteration: 5
# Mean: [151 110  93]
#
# Iteration: 6
# Mean: [151 110  94]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0016.jpg (Image: 16 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [73 52 50]
#
# Iteration: 2
# Mean: [73 52 48]
#
# Iteration: 3
# Mean: [72 51 48]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0002.jpg (Image: 17 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [157 121 111]
#
# Iteration: 2
# Mean: [155 116 104]
#
# Iteration: 3
# Mean: [149 111  99]
#
# Iteration: 4
# Mean: [141 104  94]
#
# Iteration: 5
# Mean: [133  98  89]
#
# Iteration: 6
# Mean: [127  93  85]
#
# Iteration: 7
# Mean: [123  90  83]
#
# Iteration: 8
# Mean: [121  88  81]
#
# Iteration: 9
# Mean: [119  87  80]
#
# Iteration: 10
# Mean: [118  86  80]
#
# Iteration: 11
# Mean: [118  86  79]
#
# Iteration: 12
# Mean: [117  86  79]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0014.jpg (Image: 18 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [160 116  99]
#
# Iteration: 2
# Mean: [154 113  96]
#
# Iteration: 3
# Mean: [152 111  95]
#
# Iteration: 4
# Mean: [151 111  95]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0000.jpg (Image: 19 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [32 20 14]
#
# Iteration: 2
# Mean: [38 27 26]
#
# Iteration: 3
# Mean: [44 32 30]
#
# Iteration: 4
# Mean: [49 35 33]
#
# Iteration: 5
# Mean: [54 39 37]
#
# Iteration: 6
# Mean: [61 44 41]
#
# Iteration: 7
# Mean: [70 49 46]
#
# Iteration: 8
# Mean: [80 56 52]
#
# Iteration: 9
# Mean: [89 63 58]
#
# Iteration: 10
# Mean: [94 66 61]
#
# Iteration: 11
# Mean: [96 68 62]
#
# Iteration: 12
# Mean: [97 69 63]
#
# Iteration: 13
# Mean: [98 69 63]
#
# Iteration: 14
# Mean: [98 70 63]
#
# Iteration: 15
# Mean: [98 70 64]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0001.jpg (Image: 20 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [253 244 241]
#
# Iteration: 2
# Mean: [253 236 229]
#
# Iteration: 3
# Mean: [253 236 228]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0015.jpg (Image: 21 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [154 111  92]
#
# Iteration: 2
# Mean: [152 112  96]
#
# Iteration: 3
# Mean: [152 112  97]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0011.jpg (Image: 22 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [87 58 51]
#
# Iteration: 2
# Mean: [82 58 53]
#
# Iteration: 3
# Mean: [81 57 53]
#
# Iteration: 4
# Mean: [80 57 53]
#
# Iteration: 5
# Mean: [80 57 52]
#
# Iteration: 6
# Mean: [80 56 52]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0005.jpg (Image: 23 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [155 115 103]
#
# Iteration: 2
# Mean: [145 108  97]
#
# Iteration: 3
# Mean: [138 102  92]
#
# Iteration: 4
# Mean: [132  98  88]
#
# Iteration: 5
# Mean: [128  94  86]
#
# Iteration: 6
# Mean: [125  92  84]
#
# Iteration: 7
# Mean: [123  90  82]
#
# Iteration: 8
# Mean: [121  89  81]
#
# Iteration: 9
# Mean: [120  88  80]
#
# Iteration: 10
# Mean: [119  87  79]
#
# Iteration: 11
# Mean: [118  86  79]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0004.jpg (Image: 24 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [117  87  92]
#
# Iteration: 2
# Mean: [119  88  81]
#
# Iteration: 3
# Mean: [118  86  79]
#
# Iteration: 4
# Mean: [117  85  78]
#
# Iteration: 5
# Mean: [116  84  78]
#
# Iteration: 6
# Mean: [115  84  77]
#
# Iteration: 7
# Mean: [114  83  77]
#
# Iteration: 8
# Mean: [113  83  76]
#
# Iteration: 9
# Mean: [113  82  76]
#
# Iteration: 10
# Mean: [112  82  76]
#
# Iteration: 11
# Mean: [112  82  75]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0010.jpg (Image: 25 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [34 23 25]
#
# Iteration: 2
# Mean: [39 29 29]
#
# Iteration: 3
# Mean: [43 33 33]
#
# Iteration: 4
# Mean: [49 36 36]
#
# Iteration: 5
# Mean: [56 41 41]
#
# Iteration: 6
# Mean: [63 46 45]
#
# Iteration: 7
# Mean: [68 49 48]
#
# Iteration: 8
# Mean: [72 52 50]
#
# Iteration: 9
# Mean: [74 54 52]
#
# Iteration: 10
# Mean: [76 55 53]
#
# Iteration: 11
# Mean: [78 56 53]
#
# Iteration: 12
# Mean: [79 57 54]
#
# Iteration: 13
# Mean: [80 58 55]
#
# Iteration: 14
# Mean: [81 58 55]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0006.jpg (Image: 26 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [164 127 113]
#
# Iteration: 2
# Mean: [154 117 105]
#
# Iteration: 3
# Mean: [145 109  99]
#
# Iteration: 4
# Mean: [138 103  94]
#
# Iteration: 5
# Mean: [133  98  90]
#
# Iteration: 6
# Mean: [129  95  87]
#
# Iteration: 7
# Mean: [126  93  85]
#
# Iteration: 8
# Mean: [124  91  84]
#
# Iteration: 9
# Mean: [123  90  83]
#
# Iteration: 10
# Mean: [122  89  82]
#
# Iteration: 11
# Mean: [121  89  82]
#
# Iteration: 12
# Mean: [121  88  82]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0012.jpg (Image: 27 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [126  90  82]
#
# Iteration: 2
# Mean: [132  97  83]
#
# Iteration: 3
# Mean: [138 101  87]
#
# Iteration: 4
# Mean: [143 105  90]
#
# Iteration: 5
# Mean: [147 107  92]
#
# Iteration: 6
# Mean: [148 108  93]
#
# Iteration: 7
# Mean: [149 109  93]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0013.jpg (Image: 28 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [152 112  94]
#
# Iteration: 2
# Mean: [148 107  91]
#
# Iteration: 3
# Mean: [146 106  90]
#
# Iteration: 4
# Mean: [145 106  90]
# Converged
# Finding Center of Mass...Done
#
# ========== Finding Mean for: castleP19_0007.jpg (Image: 29 / 29)==========
#
# Building Feature Space
# Building Feature Space...Done
#
# Initializing Random Seed
# Initializing Random Seed...Done
#
# Finding Center of Mass
#
# Iteration: 1
# Mean: [89 92 97]
#
# Iteration: 2
# Mean: [110  81  77]
#
# Iteration: 3
# Mean: [111  81  75]
# Converged
# Finding Center of Mass...Done
#
#  ========== subset: 0 ==========
# ['castleP19_0009.jpg', 'castleP19_0008.jpg', 'entryP10_0000.jpg', 'entryP10_0001.jpg', 'castleP19_0003.jpg', 'castleP19_0016.jpg', 'castleP19_0002.jpg', 'castleP19_0000.jpg', 'castleP19_0011.jpg', 'castleP19_0005.jpg', 'castleP19_0004.jpg', 'castleP19_0010.jpg', 'castleP19_0006.jpg', 'castleP19_0007.jpg']
#
#  ========== subset: 1 ==========
# ['castleP19_0018.jpg', 'entryP10_0003.jpg', 'entryP10_0002.jpg', 'entryP10_0005.jpg', 'entryP10_0004.jpg', 'entryP10_0006.jpg', 'entryP10_0007.jpg', 'entryP10_0009.jpg', 'entryP10_0008.jpg', 'castleP19_0017.jpg', 'castleP19_0014.jpg', 'castleP19_0015.jpg', 'castleP19_0012.jpg', 'castleP19_0013.jpg']
#
#  ========== subset: 2 ==========
# ['castleP19_0001.jpg']
