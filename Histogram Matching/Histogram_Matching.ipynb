# %% [markdown]
# ## Importing Libraries

# %%
import cv2
import matplotlib.pyplot as plt
from skimage import exposure
from google.colab.patches import cv2_imshow

# %% [markdown]
# ## Histogram Matching

# %%
# loading the image
anfield = cv2.imread('anfield.jpeg')
anfield = cv2.cvtColor(anfield, cv2.COLOR_BGR2RGB)

campNou = cv2.imread('campNou.jpeg')
campNou = cv2.cvtColor(campNou, cv2.COLOR_BGR2RGB)

# histogram matching
multi = True if anfield.shape[-1] > 1 else False
matched = exposure.match_histograms(anfield, campNou, multichannel=multi)


plt.subplot(1, 3, 1,)
plt.title("Source")
plt.axis('off')
plt.imshow(anfield)

plt.subplot(1, 3, 2)
plt.title("Reference")
plt.axis('off')
plt.imshow(campNou)

plt.subplot(1, 3, 3)
plt.title("Histogram Matched")
plt.axis('off')
plt.imshow(matched)
# Out:
# <ipython-input-9-63bdbff8cbc0>:10: FutureWarning: `multichannel` is a deprecated argument name for `match_histograms`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   matched = exposure.match_histograms(anfield, campNou, multichannel=multi)
